# %%
# !source activate python3
# !pip3 install pymongo
# !pip3 install dnspython
# !pip3 install pymongo[srv]
# !source deactivate
# Out:
# Requirement already satisfied: pymongo in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (3.10.1)
# You are using pip version 10.0.1, however version 20.2b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: dnspython in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.16.0)
# You are using pip version 10.0.1, however version 20.2b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: pymongo[srv] in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (3.10.1)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0; extra == "srv" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pymongo[srv]) (1.16.0)
# You are using pip version 10.0.1, however version 20.2b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# # Data Pull & Data Creation Pipeline

# %%
#from Data_Creation_Pipeline_2 import *

# %% [markdown]
# # Model Building Pipeline

# %%
# !python3 Recommendation_Modelling_Pipeline_2.py
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# -----------------------------------------------------------------------------------------------------
# -----------------------------  Data Creation  -------------------------------------------------------
# -----------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------
#
# Connecting to the database:
# -----------------------------------------------------------------------------------------------------
#
# Reading Feeds Data
# Feeds Data: (3623, 25)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Figure(1800x800)
# Figure(800x400)
# Figure(800x400)
# -----------------------------------------------------------------------------------------------------
#
#  Procesing Likes Data:
#
# Likes Summary:
# Total Like Count: 9946
# Total Content Like: 5667
# Unique Content Like: 1913
# Total Comment Like: 4279
# Unique Comment Like: 3377
# Average Likes on a Post:  2.962362780972295
# Figure(1800x800)
# Average Likes on a Post:  2.962362780972295
# Figure(1000x400)
# -----------------------------------------------------------------------------------------------------
#
# Procesing Bookmarks Data
#
# Bookmarks Summary:
# Total bookmarks: 383
# Unique Content with bookmark: 319
# Unique Users with bookmark: 247
# -----------------------------------------------------------------------------------------------------
#
# Procesing Comments Data
#
# Comments Summary:
# Data Size: 10626
# Total Comments: 10626
# Total Post with comments: 2747
# Total Primary Comments: 7540
# Total SubComments: 3086
# Average Comments on a Post:  3.868219876228613
# Figure(1800x800)
# Average Comments on a Post:  3.868219876228613
# Figure(1000x400)
# -----------------------------------------------------------------------------------------------------
#
# Creating Interactions Data:
#
# Post Likes: (5606, 9)
# Train (10588, 9)
# Test (2017, 9)
# -----------------------------------------------------------------------------------------------------
# ------------------------------------  Model Development ---------------------------------------------
# -----------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------
# Computing Event Strength
# -----------------------------------------------------------------------------------------------------
# Identifying users with single or multiple interactions
# # users: 3186
# # users with 1 interactions: 1922
# # users with at least 2 interactions: 1264
# # of interactions: 19671
# # of interactions from users with at least 2 interactions: 16887
# # of interactions: 19671
# # of interactions from users with 1 interaction: 2784
# # of unique user/item multiple interactions: 12605
# # of unique user/item single interactions: 1922
# -----------------------------------------------------------------------------------------------------
# Clustering Users based on number of interactions for model evaluation by cluster
# -----------------------------------------------------------------------------------------------------
# Divide the data into Train Test Sample:
# # interactions on Multi Train set: 10588
# # interactions on Multi Test set (These are old customers with History): 2017
# # interactions on Single Train set: 1337
# # interactions on Single Test set (These are new customers with no History): 585
# N_test_cases:  (2017, 3)
# add_rest_to_train:  (0, 3)
# # interactions on Multi Train set: 10588
# # interactions on Multi Test set (These are old customers with History): 2017
# -----------------------------------------------------------------------------------------------------
# ----------------------------------------  Popularity Model ------------------------------------------
# Evaluating Popularity recommendation model...
# 1848 users processed
# 0 person with zero recos
#
# Global metrics:
# {'modelName': 'Popularity', 'recall@5': 0.2609531129900077, 'recall@10': 0.3458877786318217, 'recall@all': 0.21983089930822444}
# Coverage: 0.0076726342710997444
# -----------------------------------------------------------------------------------------------------
# -------------------------------------  Content Based Model ------------------------------------------
# Evaluating Content-Based Filtering model...
# 1848 users processed
# 0 person with zero recos
#
# Global metrics:
# {'modelName': 'Content-Based', 'recall@5': 0.20330514988470408, 'recall@10': 0.24289008455034589, 'recall@all': 0.16833205226748654}
# Content Based Model:  0.21616261774913237 for  1264  Users
# Popularity Model:  0.335042735042735 for  585  Users
# Coverage: 0.22563228189826656
# -----------------------------------------------------------------------------------------------------
# -------------------------------  SVD based Collaborative Filtering Model ----------------------------
# U (2601, 20)
# Vt (20, 3372)
# sigma (20, 20)
# Evaluating Collaborative Filtering (SVD Matrix Factorization) model...
# 1848 users processed
# 0 person with zero recos
#
# Global metrics:
# {'modelName': 'Collaborative Filtering', 'recall@5': 0.19523443504996157, 'recall@10': 0.2605687932359723, 'recall@all': 0.16333589546502691}
# Collaborative Filtering:  0.2389687654933069 for  1264  Users
# Popularity Model:  0.335042735042735 for  585  Users
# Coverage: 0.08695652173913043
# U_all (3186, 20)
# Vt_all (20, 3519)
# sigma_all (20, 20)
# (3186, 3519)
# -----------------------------------------------------------------------------------------------------
# --------------------------  User to User Collaborative Filtering Model ------------------------------
# Evaluating User to User Collaborative Filtering.....
# 1848 users processed
# 13 person with zero recos
#
# Global metrics:
# {'modelName': 'User-to-User', 'recall@5': 0.14873174481168333, 'recall@10': 0.15526518063028438, 'recall@all': 0.14296694850115296}
# User to User:  0.10312345066931086 for  1264  Users
# Popularity Model:  0.335042735042735 for  585  Users
# Coverage: 0.022733731173628872
# -----------------------------------------------------------------------------------------------------
# -------------------------------------------  Hybrid Model -------------------------------------------
# Evaluating Hybrid model...
# 1848 users processed
# 0 person with zero recos
#
# Global metrics:
# {'modelName': 'Hybrid', 'recall@5': 0.20561106840891621, 'recall@10': 0.28132205995388165, 'recall@all': 0.16410453497309763}
# Hybrid Model:  0.26574119980168565 for  1264  Users
# Popularity Model:  0.335042735042735 for  585  Users
# Coverage: 0.19437340153452684
